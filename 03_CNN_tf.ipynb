# %% [markdown]
# <a href="https://colab.research.google.com/github/ucoskun/ml-notes/blob/main/03_CNN_tf.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.datasets import load_sample_image
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
from tensorflow import keras

# %%
china = load_sample_image("china.jpg") / 255
flower = load_sample_image("flower.jpg") / 255
plt.imshow(flower)

# %%
images = np.array([china, flower])
batch_size, height, width, channels = images.shape
print(images.shape)

# Create 2 filters manually

filters = np.zeros(shape=(21, 21, channels, 2), dtype=np.float32)

filters[:, 10, :, 0] = 1
filters[10, :, :, 1] = 1

outputs = tf.nn.conv2d(images, filters, strides=1, padding="SAME")

plt.imshow(outputs[1, :, :, 0], cmap="gray")
# Out:
# (2, 427, 640, 3)

# %%
# Define filters as trainable variables

conv = keras.layers.Conv2D(filters=32, kernel_size=3, strides=1, padding="SAME", activation="relu")

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-33-fb20d49a1e06> in <module>()
# ----> 1 plt.imshow(conv[1, :, :, 0], cmap="gray")
#
# TypeError: 'Conv2D' object is not subscriptable
